# %%
pwd
# Out:
# 'C:\\Users\\david'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tabulate as tabulate
# %matplotlib inline

terror=pd.read_csv(r'C:\Users\david\Desktop\Personal Projects\Global Terrorism Data.csv', encoding='ISO-8859-1', low_memory=False)

# %% [markdown]
# Our data has 453 rows and 4 columns.

# %%
terror['attacktype1_txt'].unique()
# Out:
# array(['Assassination', 'Hostage Taking (Kidnapping)',
#        'Bombing/Explosion', 'Facility/Infrastructure Attack',
#        'Armed Assault', 'Hijacking', 'Unknown', 'Unarmed Assault',
#        'Hostage Taking (Barricade Incident)'], dtype=object)

# %%
plt.hist(terror['attacktype1_txt'], label='Attack Methods')
plt.xticks(rotation=35)
plt.xlabel('Methods of Attack')
plt.ylabel('Frequency')
plt.show()
